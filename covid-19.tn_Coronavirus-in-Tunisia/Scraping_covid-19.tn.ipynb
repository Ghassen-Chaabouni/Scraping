</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-14 </td><td _ngcontent-wwu-c96="" class="table-light"> 47 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Tataouine, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 16 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-13 </td><td _ngcontent-wwu-c96="" class="table-light"> 27 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Tunis, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-11 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 15 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-13 </td><td _ngcontent-wwu-c96="" class="table-light"> 40 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Ariana, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-01 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 14 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-13 </td><td _ngcontent-wwu-c96="" class="table-light"> 45 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Bizerte, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 13 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 53 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Tunis, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-11 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 12 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 36 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Tunis, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-10 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 11 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 28 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Tunis, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-10 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 10 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 34 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Ariana, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-10 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 9 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 35 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Ariana, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 8 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="table-light"> 1 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Ariana, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-12 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 7 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-11 </td><td _ngcontent-wwu-c96="" class="table-light"> 40 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Ariana, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-02 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 6 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-10 </td><td _ngcontent-wwu-c96="" class="table-light"> 62 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Mahdia, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-07 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 5 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-09 </td><td _ngcontent-wwu-c96="" class="table-light"> 83 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Bizerte, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-04 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 4 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-09 </td><td _ngcontent-wwu-c96="" class="table-light"> 35 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Tunis, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-08 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 3 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-09 </td><td _ngcontent-wwu-c96="" class="table-light"> 54 </td><td _ngcontent-wwu-c96="" class="table-light"> Féminin </td><td _ngcontent-wwu-c96="">Mahdia, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-04 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 2 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-08 </td><td _ngcontent-wwu-c96="" class="table-light"> 64 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Mahdia, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-03 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true">help </mat-icon><!----></td></tr><!----><!----><tr _ngcontent-wwu-c96="" class="ng-star-inserted"><td _ngcontent-wwu-c96="" class="table-light"> 1 </td><td _ngcontent-wwu-c96="" class="table-light"> 2020-03-02 </td><td _ngcontent-wwu-c96="" class="table-light"> 40 </td><td _ngcontent-wwu-c96="" class="table-light"> Masculin </td><td _ngcontent-wwu-c96="">Gafsa, Tunisia</td><td _ngcontent-wwu-c96="" class="table-light"> 2020-02-29 </td><td _ngcontent-wwu-c96="" class="td-help"><mat-icon _ngcontent-wwu-c96="" role="img" class="mat-icon notranslate icon material-icons mat-icon-no-color" aria-hidden="true" style="color: rgb(188, 188, 188);">help </mat-icon><div _ngcontent-wwu-c96="" class="tool ng-star-inserted"> Le 02 Mars 2020, un cas confirmé d’infection par le SARS-Cov-2 a été identifié en Tunisie : C’est un cas importé de l’Italie, identifié dans le cadre du suivi des voyageurs en provenance des zones à risque. Il s’agit d’un sujet de sexe masculin, de nationalité tunisienne, il est rentré en Tunisie le 27 Février 2020, il était apyrétique lors du dépistage à l’entrée en Tunisie et a été mis en auto- isolement à domicile. Le 29 Février, il a présenté une fièvre non chiffrée et une toux sèche suite auxquels il a appelé le SAMU 190 le 01 Mars. Un prélèvement nasopharyngé a été fait et le résultat était positif au SARS-CoV-2. Tous les contacts étroits familiaux, communautaires et pendant le voyage (à bord du bateau) de même que les membres de l’équipage et le personnel du contrôle de sécurité ont été tracé, prélevés et testé, et mis en auto-isolement et seront suivi pendant 14 Jours. Le cas est actuellement asymptomatique et continue à suivre l’auto- isolement. La déclaration de guérison sera faite après l’obtention de deux prélèvements différents négatifs à 48H d’intervalle.  </div><!----></td></tr><!----><!----><!----></table>'

# %%
data = pd.read_html(ch)
data = data[0]
data
# Out:
#     Cas Date de confirmation   Age     Genre       Gouvernorat  \
# 0    89           2020-03-22  46.0  Masculin  Mednine, Tunisia
# 1    88           2020-03-22  63.0   Féminin  Mednine, Tunisia
# 2    87           2020-03-22  40.0  Masculin    Tunis, Tunisia
# 3    86           2020-03-22  57.0   Féminin   Ariana, Tunisia
# 4    85           2020-03-22  61.0  Masculin  Manouba, Tunisia
# ..  ...                  ...   ...       ...               ...
# 84    5           2020-03-09  83.0  Masculin  Bizerte, Tunisia
# 85    4           2020-03-09  35.0   Féminin    Tunis, Tunisia
# 86    3           2020-03-09  54.0   Féminin   Mahdia, Tunisia
# 87    2           2020-03-08  64.0  Masculin   Mahdia, Tunisia
# 88    1           2020-03-02  40.0  Masculin    Gafsa, Tunisia
#
#    Symptomatique à                                 Plus dinformations
# 0       2020-03-14                                               help
# ...

# %%
data.rename({'Date de confirmation': 'confirmation_date'}, axis=1, inplace=True)
data.rename({'Age': 'age'}, axis=1, inplace=True)
data.rename({'Gouvernorat': 'city'}, axis=1, inplace=True)
data.rename({'Cas': 'case'}, axis=1, inplace=True)
data.rename({'Genre': 'gender'}, axis=1, inplace=True)
data.rename({'Symptomatique à': 'symptomatic'}, axis=1, inplace=True)
data = data.drop('Plus dinformations', 1)

# %%
return_from = ['Local', 'Local', 'Local', 'Local', 'France', 'Local', 'France', 'Espagne', 'France', 'France', 'France', 'Local', 'Local', 'Local', 'France', 'Local', 'Etats Unis', 'France', 'France', 'Turquie', 'France', 'France', 'Turquie', 'France', 'France', 'Turquie', 'France', 'Local', 'France', 'France', 'France', 'Local', 'Angleterre', 'France', 'France', 'Vietnam', 'Local', 'Allemagne', 'France', 'France', 'Local', 'France', 'Espagne', 'Espagne', 'Turquie', 'France', 'Local', 'France', 'Turquie', 'Espagne', 'Angleterre', 'Angleterre', 'Local', 'Italie', 'Egypte', 'France', 'France', 'France', 'France', 'Local', 'Egypte', 'Local', 'Espagne', 'Local','Turquie'
              ,'Local', 'France', 'France', 'Local', 'France', 'France', 'Local', 'France', 'Local', 'Egypte', 'Local', 'France', 'France', 'Local', 'Local', 'Local', 'Local', 'Egypte', 'Local', 'France', 'Italie', 'Local', 'Italie', 'Italie']

# %%
data['return_from']=return_from

# %%
L = str(list(data["city"])).split("'")
length=len(L)-1
i=0
while(i<=length):
    if(L[i]=="[" or L[i]=="]" or L[i]==", "):
        L.pop(i)
        length-=1
    i+=1

city1 = []
city2 = []
for i in range(len(L)):
    L2 = L[i].split(", ")
    if(len(L2)==2):
        city1.append(L2[0])
        city2.append(L2[1])
    elif(len(L2)==1):
        city1.append("0")
        city2.append(L2[0])

# %%
data["country"] = city2
data["city"] = city1

# %%
data
# Out:
#     case confirmation_date   age    gender     city symptomatic return_from  \
# 0     89        2020-03-22  46.0  Masculin  Mednine  2020-03-14       Local
# 1     88        2020-03-22  63.0   Féminin  Mednine  2020-03-14       Local
# 2     87        2020-03-22  40.0  Masculin    Tunis  2020-03-19       Local
# 3     86        2020-03-22  57.0   Féminin   Ariana  2020-03-21       Local
# 4     85        2020-03-22  61.0  Masculin  Manouba  2020-03-16      France
# ..   ...               ...   ...       ...      ...         ...         ...
# 84     5        2020-03-09  83.0  Masculin  Bizerte  2020-03-04      France
# 85     4        2020-03-09  35.0   Féminin    Tunis  2020-03-08      Italie
# 86     3        2020-03-09  54.0   Féminin   Mahdia  2020-03-04       Local
# 87     2        2020-03-08  64.0  Masculin   Mahdia  2020-03-03      Italie
# 88     1        2020-03-02  40.0  Masculin    Gafsa  2020-02-29      Italie
#
#     country
# 0   Tunisia
# 1   Tunisia
# 2   Tunisia
# ...

# %%
data.to_csv("./Coronavirus_Tunisia_updated.csv", index=False)
